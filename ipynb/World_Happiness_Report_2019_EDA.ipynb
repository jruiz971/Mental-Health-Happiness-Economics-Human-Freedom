# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv( "../datasets/World Happiness Report_2019.csv")
df
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                   Finland  7.769           1.340
# 1               2                   Denmark  7.600           1.383
# 2               3                    Norway  7.554           1.488
# 3               4                   Iceland  7.494           1.380
# 4               5               Netherlands  7.488           1.396
# ..            ...                       ...    ...             ...
# 151           152                    Rwanda  3.334           0.359
# 152           153                  Tanzania  3.231           0.476
# 153           154               Afghanistan  3.203           0.350
# 154           155  Central African Republic  3.083           0.026
# 155           156               South Sudan  2.853           0.306
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             1.587                    0.986                         0.596
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Overall rank                  156 non-null    int64
#  1   Country or region             156 non-null    object
#  2   Score                         156 non-null    float64
#  3   GDP per capita                156 non-null    float64
#  4   Social support                156 non-null    float64
#  5   Healthy life expectancy       156 non-null    float64
#  6   Freedom to make life choices  156 non-null    float64
#  7   Generosity                    156 non-null    float64
#  8   Perceptions of corruption     156 non-null    float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 11.1+ KB

# %% [markdown]
# ## Valores faltantes

# %%
print("Are There Missing Data? :",df.isnull().any().any())
print(df.isnull().sum())
# Out:
# Are There Missing Data? : False
# Overall rank                    0
# Country or region               0
# Score                           0
# GDP per capita                  0
# Social support                  0
# Healthy life expectancy         0
# Freedom to make life choices    0
# Generosity                      0
# Perceptions of corruption       0
# dtype: int64

# %% [markdown]
# ## ¿Qué países son los más felices?

# %%
df_selected = df.iloc[np.r_[0:20, -20:0]]

# %%
plt.figure(figsize=(12,10))
sns.barplot(x=df_selected['Country or region'], y=df_selected['Score'],palette=sns.cubehelix_palette(len(df_selected)))
# Place the region names at a 90-degree angle.
plt.xticks(rotation= 90)
plt.xlabel('Country')
plt.ylabel('Happiness Score')
plt.title('the 20 happiest countries and 20 unhappiest countries in the world')
plt.show()

# %% [markdown]
# ## Paises con mayor GDP per cápita

# %%
#(df['Country or region'].head(10)) and (df['Country or region'].tail(10))
plt.figure(figsize=(12,10))
sns.barplot(x=df_selected['Country or region'], y=df_selected['GDP per capita'],palette=sns.cubehelix_palette(len(df_selected)))
# Place the region names at a 90-degree angle.
plt.xticks(rotation= 90)
plt.xlabel('Country')
plt.ylabel('GDP Per Capita')
plt.title('GDP Per Capita of 20 happier countries vs Social Support of 10 unhappier countries')
plt.show()

# %% [markdown]
# ## Social Support of 10 happier countries vs Social Support of 10 unhappier countries

# %%
#(df['Country or region'].head(10)) and (df['Country or region'].tail(10))
plt.figure(figsize=(12,10))
sns.barplot(x=df_selected['Country or region'], y=df_selected['Social support'],palette=sns.cubehelix_palette(len(df_selected)))
# Place the region names at a 90-degree angle.
plt.xticks(rotation= 90)
plt.xlabel('Country')
plt.ylabel('Social support index')
plt.title('Social Support of 20 happier countries vs Social Support of 10 unhappier countries')
plt.show()

# %% [markdown]
# Healthy life expectancy         0
# Freedom to make life choices    0
# Generosity                      0
# Perceptions of corruption

# %%
plt.figure(figsize=(12,10))
sns.barplot(x=df_selected['Country or region'], y=df_selected['Healthy life expectancy'],palette=sns.cubehelix_palette(len(df_selected)))
# Place the region names at a 90-degree angle.
plt.xticks(rotation= 90)
plt.xlabel('Country')
plt.ylabel('Healthy life expectancy')
plt.title('Healthy life expectancy of 10 happier countries vs Social Support of 10 unhappier countries')
plt.show()

# %%
plt.figure(figsize=(12,10))
sns.barplot(x=df_selected['Country or region'], y=df_selected['Freedom to make life choices'],palette=sns.cubehelix_palette(len(df_selected)))
# Place the region names at a 90-degree angle.
plt.xticks(rotation= 90)
plt.xlabel('Country')
plt.ylabel('Freedom to make life choices')
plt.title('Freedom to make life choices of 10 happier countries vs Social Support of 10 unhappier countries')
plt.show()

# %% [markdown]
# ## ¿Qué factores influyen más en la felicidad de los países?

# %%
countries_selected = df.iloc[np.r_[0:7, -7:0]]

# %%
countries_selected['GDP per capita']
# Out:
# 0      1.340
# 1      1.383
# 2      1.488
# 3      1.380
# 4      1.396
# 5      1.452
# 6      1.387
# 149    0.191
# 150    0.287
# 151    0.359
# 152    0.476
# 153    0.350
# 154    0.026
# 155    0.306
# Name: GDP per capita, dtype: float64

# %% [markdown]
# 4   Social support
# 5   Healthy life expectancy
# 6   Freedom to make life choices
# 7   Generosity
# 8   Perceptions of corruption

# %%
f,ax = plt.subplots(figsize = (9,5))
#sns.set_color_codes("pastel")
sns.barplot(x=countries_selected['Social support'],y=countries_selected['Country or region'],color='b',label="Social support")

#sns.barplot(x=countries_selected['Generosity'],y=countries_selected['Country or region'],color='c',label="Generosity")

sns.barplot(x=countries_selected['GDP per capita'],y=countries_selected['Country or region'],color='r',label="Economy")
sns.barplot(x=countries_selected['Healthy life expectancy'],y=countries_selected['Country or region'],color='g',label="Healty")
sns.barplot(x=countries_selected['Freedom to make life choices'],y=countries_selected['Country or region'],color='y',label="Freedom to make life choices")
sns.barplot(x=countries_selected['Perceptions of corruption'],y=countries_selected['Country or region'],color='k',label="Perceptions of corruption")
ax.legend(loc="lower right",frameon = True)
ax.set(xlabel='Percentage of Region', ylabel='Region',title = "Factors affecting happiness score")
plt.show()
